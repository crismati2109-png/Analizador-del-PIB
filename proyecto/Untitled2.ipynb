# %%
import pandas as pd
df = pd.read_csv('pib.csv')

# %%
df
# Out:
#      Unnamed: 0     Country Name Country Code      1961      1962      1963  \
# 0             0            Aruba          ABW       NaN       NaN       NaN
# 1             1              NaN          AFE  0.418605  7.937089  5.624317
# 2             2       Afganistán          AFG       NaN       NaN       NaN
# 3             3              NaN          AFW  1.869593  3.726016  7.038172
# 4             4           Angola          AGO       NaN       NaN       NaN
# ..          ...              ...          ...       ...       ...       ...
# 260         260           Kosovo          XKX       NaN       NaN       NaN
# 261         261  Yemen, Rep. del          YEM       NaN       NaN       NaN
# 262         262        Sudáfrica          ZAF  3.844734  6.177931  7.373709
# 263         263           Zambia          ZMB  1.361382 -2.490839  3.272393
# 264         264         Zimbabwe          ZWE  6.316157  1.434471  6.244345
#
# ...

# %%
#aqui podemos ver que tiene 265 filas y 68 columnas, podemos ver que las
columnas son el nombre del pais, el codigo del pais, y los años

# %%
df.head(25)
# Out:
#     Unnamed: 0            Country Name Country Code       1961       1962  \
# 0            0                   Aruba          ABW        NaN        NaN
# 2            2              Afganistán          AFG        NaN        NaN
# 4            4                  Angola          AGO        NaN        NaN
# 5            5                 Albania          ALB        NaN        NaN
# 6            6                 Andorra          AND        NaN        NaN
# 7            7          El mundo árabe          ARB        NaN        NaN
# 8            8  Emiratos Árabes Unidos          ARE        NaN        NaN
# 9            9               Argentina          ARG   5.427843  -0.852022
# 10          10                 Armenia          ARM        NaN        NaN
# 11          11         Samoa Americana          ASM        NaN        NaN
# 12          12       Antigua y Barbuda          ATG        NaN        NaN
# 13          13               Australia          AUS   2.480857   1.296932
# ...

# %%
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.dropna(subset=['Country Name'])

# %%
aqui borramos los datos na ya que no correspondian a codigos de pais y borramos la columna unnamed: 0 
ya que no nos sirve

# %%
df
# Out:
#         Country Name Country Code      1961      1962      1963       1964  \
# 0              Aruba          ABW       NaN       NaN       NaN        NaN
# 2         Afganistán          AFG       NaN       NaN       NaN        NaN
# 4             Angola          AGO       NaN       NaN       NaN        NaN
# 5            Albania          ALB       NaN       NaN       NaN        NaN
# 6            Andorra          AND       NaN       NaN       NaN        NaN
# ..               ...          ...       ...       ...       ...        ...
# 260           Kosovo          XKX       NaN       NaN       NaN        NaN
# 261  Yemen, Rep. del          YEM       NaN       NaN       NaN        NaN
# 262        Sudáfrica          ZAF  3.844734  6.177931  7.373709   7.939609
# 263           Zambia          ZMB  1.361382 -2.490839  3.272393  12.214048
# 264         Zimbabwe          ZWE  6.316157  1.434471  6.244345  -1.106172
#
# ...

# %%
ocde_codes = [
    'AUS', 'AUT', 'BEL', 'CAN', 'CHL', 'COL', 'CRI', 'CZE', 'DNK', 'EST',
    'FIN', 'FRA', 'DEU', 'GRC', 'HUN', 'ISL', 'IRL', 'ISR', 'ITA', 'JPN',
    'KOR', 'LVA', 'LTU', 'LUX', 'MEX', 'NLD', 'NZL', 'NOR', 'POL', 'PRT',
    'SVK', 'SVN', 'ESP', 'SWE', 'CHE', 'TUR', 'GBR', 'USA'
]

# %%
df_ocde = df[df['Country Code'].isin(ocde_codes)]

# %%
df_ocde
# Out:
#             Country Name Country Code       1961       1962       1963  \
# 13             Australia          AUS   2.480857   1.296932   6.214376
# 14               Austria          AUT   5.537979   2.648675   4.138268
# 17               Bélgica          BEL   4.978423   5.212003   4.351584
# 35                Canadá          CAN   3.163292   7.427837   5.297440
# 37                 Suiza          CHE   5.681293   4.259047   5.327934
# 39                 Chile          CHL   5.519611   3.930785   5.686672
# 45              Colombia          COL   5.089217   5.411890   3.286708
# 48            Costa Rica          CRI   1.879277   5.442391   6.898923
# 54       República Checa          CZE        NaN        NaN        NaN
# 55              Alemania          DEU   4.298440   4.623471   2.735296
# 58             Dinamarca          DNK   6.378832   5.666822   0.637021
# 70                España          ESP  11.838674   9.953438   9.596499
# ...

# %%
df_ocde.to_csv("datos_ocde.csv", index=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Matias
